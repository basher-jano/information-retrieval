# %%
import pandas as pd
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import json
from scipy import sparse
import csv
import pickle
import numpy as np
from gensim.models import Word2Vec
import nltk
from sklearn.preprocessing import normalize

# %%
clean_docs = pd.read_csv('science_dataset/processed_documents.csv')
clean_docs = clean_docs.fillna('')
original_docs = pd.read_csv('science_dataset/original_documents.csv')
original_docs = original_docs.fillna('')
clean_queries = pd.read_csv("science_dataset/processed_queries.csv")

# %%
json_qrles_list = []
links = {}
qrels = []
with open('science_dataset/qrels.jsonl', 'r', encoding='utf-8') as f:
    # Read the file line by line
    
    for line in f:
        # Load each line as a JSON object
        data = json.loads(line)
        json_qrles_list.append(data)
        # Process the data (e.g., print, store in a list)
    for data in json_qrles_list:
        
        qid = str(data['qid'])
        answer_pids = data['answer_pids']
        links[qid] = answer_pids

# %%
with open('science_dataset/word_embedding/tokenized_docs.pkl', 'rb') as file:
    tokenized_docs = pickle.load(file)

# %%
# with open('science_dataset/word_embedding/model1.pkl', 'rb') as file:
#     model1 = pickle.load(file)
with open('science_dataset/word_embedding/model_min_count=3,vector_size=100,window=20,sg=1.pkl', 'rb') as file:
    model = pickle.load(file)

# %%
# Load the vectorizer object
with open('science_dataset/objects/vectorizer.pkl', 'rb') as file:
    vectorizer = pickle.load(file)
# Load the vectorized_docs object
with open('science_dataset/objects/vectorized_docs.pkl', 'rb') as file:
    vectorized_docs = pickle.load(file)

# %%
with open('science_dataset/word_embedding/tokenized_queries.pkl', 'rb') as file:
    tokenized_queries = pickle.load(file)

# %%
combined_embeddings = np.load("science_dataset/word_embedding/combined_embeddings_model_min_count=3,vector_size=100,window=20,sg=1.npy")

# %%
# combined_embeddings = np.load("science_dataset/word_embedding/combined_embeddings_model_min_count=3,vector_size=100,window=20,sg=1.npy")

# Prepare data for Chroma
ids = [str(tokenized_docs[i]['doc_id']) for i, embedding in enumerate(combined_embeddings) if np.any(embedding)]
embeddings = [embedding.tolist() for embedding in combined_embeddings if np.any(embedding)]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 4
#       1 # combined_embeddings = np.load("science_dataset/word_embedding/combined_embeddings_model_min_count=3,vector_size=100,window=20,sg=1.npy")
#       2
#       3 # Prepare data for Chroma
# ----> 4 ids = [str(tokenized_docs[i]['doc_id']) for i, embedding in enumerate(combined_embeddings) if np.any(embedding)]
#       5 embeddings = [embedding.tolist() for embedding in combined_embeddings if np.any(embedding)]
#       7 # Batch size for upsert (adjust as needed)
#
# Cell In[64], line 4, in <listcomp>(.0)
#       1 # combined_embeddings = np.load("science_dataset/word_embedding/combined_embeddings_model_min_count=3,vector_size=100,window=20,sg=1.npy")
#       2
#       3 # Prepare data for Chroma
# ----> 4 ids = [str(tokenized_docs[i]['doc_id']) for i, embedding in enumerate(combined_embeddings) if np.any(embedding)]
#       5 embeddings = [embedding.tolist() for embedding in combined_embeddings if np.any(embedding)]
#       7 # Batch size for upsert (adjust as needed)
#
# KeyboardInterrupt:

# %%
import pinecone

from pinecone import Pinecone

pc = Pinecone(api_key="5ba8ab95-63a1-437d-ac9f-4a2b9d830981")
index = pc.Index("science-word-embedding")

# %%
# Batch size for upsert (adjust as needed)
batch_size = 500

# Upsert in batches
for i in range(0, len(ids), batch_size):
    batch_ids = ids[i:i + batch_size]
    batch_embeddings = embeddings[i:i + batch_size]
    index.upsert(vectors=[{"id": id_, "values": vec} for id_, vec in zip(batch_ids, batch_embeddings)])
    print(f"Upserted batch {i//batch_size + 1}/{(len(ids) + batch_size - 1)//batch_size}")

print("Data upserted successfully.")
# Out:
# Upserted batch 1/688
# Upserted batch 2/688
# Upserted batch 3/688
# Upserted batch 4/688
# Upserted batch 5/688
# Upserted batch 6/688
# Upserted batch 7/688
# Upserted batch 8/688
# Upserted batch 9/688
# Upserted batch 10/688
# Upserted batch 11/688
# Upserted batch 12/688
# Upserted batch 13/688
# Upserted batch 14/688
# Upserted batch 15/688
# Upserted batch 16/688
# Upserted batch 17/688
# Upserted batch 18/688
# Upserted batch 19/688
# Upserted batch 20/688
# Upserted batch 21/688
# Upserted batch 22/688
# Upserted batch 23/688
# Upserted batch 24/688
# Upserted batch 25/688
# Upserted batch 26/688
# Upserted batch 27/688
# Upserted batch 28/688
# Upserted batch 29/688
# Upserted batch 30/688
# Upserted batch 31/688
# Upserted batch 32/688
# Upserted batch 33/688
# Upserted batch 34/688
# Upserted batch 35/688
# Upserted batch 36/688
# Upserted batch 37/688
# Upserted batch 38/688
# Upserted batch 39/688
# Upserted batch 40/688
# Upserted batch 41/688
# Upserted batch 42/688
# Upserted batch 43/688
# Upserted batch 44/688
# Upserted batch 45/688
# Upserted batch 46/688
# Upserted batch 47/688
# Upserted batch 48/688
# Upserted batch 49/688
# Upserted batch 50/688
# Upserted batch 51/688
# Upserted batch 52/688
# Upserted batch 53/688
# Upserted batch 54/688
# Upserted batch 55/688
# Upserted batch 56/688
# Upserted batch 57/688
# Upserted batch 58/688
# Upserted batch 59/688
# Upserted batch 60/688
# Upserted batch 61/688
# Upserted batch 62/688
# Upserted batch 63/688
# Upserted batch 64/688
# Upserted batch 65/688
# Upserted batch 66/688
# Upserted batch 67/688
# Upserted batch 68/688
# Upserted batch 69/688
# Upserted batch 70/688
# Upserted batch 71/688
# Upserted batch 72/688
# Upserted batch 73/688
# Upserted batch 74/688
# Upserted batch 75/688
# Upserted batch 76/688
# Upserted batch 77/688
# Upserted batch 78/688
# Upserted batch 79/688
# Upserted batch 80/688
# Upserted batch 81/688
# Upserted batch 82/688
# Upserted batch 83/688
# Upserted batch 84/688
# Upserted batch 85/688
# Upserted batch 86/688
# Upserted batch 87/688
# Upserted batch 88/688
# Upserted batch 89/688
# Upserted batch 90/688
# Upserted batch 91/688
# Upserted batch 92/688
# Upserted batch 93/688
# Upserted batch 94/688
# Upserted batch 95/688
# Upserted batch 96/688
# Upserted batch 97/688
# Upserted batch 98/688
# Upserted batch 99/688
# Upserted batch 100/688
# Upserted batch 101/688
# Upserted batch 102/688
# Upserted batch 103/688
# Upserted batch 104/688
# Upserted batch 105/688
# Upserted batch 106/688
# Upserted batch 107/688
# Upserted batch 108/688
# Upserted batch 109/688
# Upserted batch 110/688
# Upserted batch 111/688
# Upserted batch 112/688
# Upserted batch 113/688
# Upserted batch 114/688
# Upserted batch 115/688
# Upserted batch 116/688
# Upserted batch 117/688
# Upserted batch 118/688
# Upserted batch 119/688
# Upserted batch 120/688
# Upserted batch 121/688
# Upserted batch 122/688
# Upserted batch 123/688
# Upserted batch 124/688
# Upserted batch 125/688
# Upserted batch 126/688
# Upserted batch 127/688
# Upserted batch 128/688
# Upserted batch 129/688
# Upserted batch 130/688
# Upserted batch 131/688
# Upserted batch 132/688
# Upserted batch 133/688
# Upserted batch 134/688
# Upserted batch 135/688
# Upserted batch 136/688
# Upserted batch 137/688
# Upserted batch 138/688
# Upserted batch 139/688
# Upserted batch 140/688
# Upserted batch 141/688
# Upserted batch 142/688
# Upserted batch 143/688
# Upserted batch 144/688
# Upserted batch 145/688
# Upserted batch 146/688
# Upserted batch 147/688
# Upserted batch 148/688
# Upserted batch 149/688
# Upserted batch 150/688
# Upserted batch 151/688
# Upserted batch 152/688
# Upserted batch 153/688
# Upserted batch 154/688
# Upserted batch 155/688
# Upserted batch 156/688
# Upserted batch 157/688
# Upserted batch 158/688
# Upserted batch 159/688
# Upserted batch 160/688
# Upserted batch 161/688
# Upserted batch 162/688
# Upserted batch 163/688
# Upserted batch 164/688
# Upserted batch 165/688
# Upserted batch 166/688
# Upserted batch 167/688
# Upserted batch 168/688
# Upserted batch 169/688
# Upserted batch 170/688
# Upserted batch 171/688
# Upserted batch 172/688
# Upserted batch 173/688
# Upserted batch 174/688
# Upserted batch 175/688
# Upserted batch 176/688
# Upserted batch 177/688
# Upserted batch 178/688
# Upserted batch 179/688
# Upserted batch 180/688
# Upserted batch 181/688
# Upserted batch 182/688
# Upserted batch 183/688
# Upserted batch 184/688
# Upserted batch 185/688
# Upserted batch 186/688
# Upserted batch 187/688
# Upserted batch 188/688
# Upserted batch 189/688
# Upserted batch 190/688
# Upserted batch 191/688
# Upserted batch 192/688
# Upserted batch 193/688
# Upserted batch 194/688
# Upserted batch 195/688
# Upserted batch 196/688
# Upserted batch 197/688
# Upserted batch 198/688
# Upserted batch 199/688
# Upserted batch 200/688
# Upserted batch 201/688
# Upserted batch 202/688
# Upserted batch 203/688
# Upserted batch 204/688
# Upserted batch 205/688
# Upserted batch 206/688
# Upserted batch 207/688
# Upserted batch 208/688
# Upserted batch 209/688
# Upserted batch 210/688
# Upserted batch 211/688
# Upserted batch 212/688
# Upserted batch 213/688
# Upserted batch 214/688
# Upserted batch 215/688
# Upserted batch 216/688
# Upserted batch 217/688
# Upserted batch 218/688
# Upserted batch 219/688
# Upserted batch 220/688
# Upserted batch 221/688
# Upserted batch 222/688
# Upserted batch 223/688
# Upserted batch 224/688
# Upserted batch 225/688
# Upserted batch 226/688
# Upserted batch 227/688
# Upserted batch 228/688
# Upserted batch 229/688
# Upserted batch 230/688
# Upserted batch 231/688
# Upserted batch 232/688
# Upserted batch 233/688
# Upserted batch 234/688
# Upserted batch 235/688
# Upserted batch 236/688
# Upserted batch 237/688
# Upserted batch 238/688
# Upserted batch 239/688
# Upserted batch 240/688
# Upserted batch 241/688
# Upserted batch 242/688
# Upserted batch 243/688
# Upserted batch 244/688
# Upserted batch 245/688
# Upserted batch 246/688
# Upserted batch 247/688
# Upserted batch 248/688
# Upserted batch 249/688
# Upserted batch 250/688
# Upserted batch 251/688
# Upserted batch 252/688
# Upserted batch 253/688
# Upserted batch 254/688
# Upserted batch 255/688
# Upserted batch 256/688
# Upserted batch 257/688
# Upserted batch 258/688
# Upserted batch 259/688
# Upserted batch 260/688
# Upserted batch 261/688
# Upserted batch 262/688
# Upserted batch 263/688
# Upserted batch 264/688
# Upserted batch 265/688
# Upserted batch 266/688
# Upserted batch 267/688
# Upserted batch 268/688
# Upserted batch 269/688
# Upserted batch 270/688
# Upserted batch 271/688
# Upserted batch 272/688
# Upserted batch 273/688
# Upserted batch 274/688
# Upserted batch 275/688
# Upserted batch 276/688
# Upserted batch 277/688
# Upserted batch 278/688
# Upserted batch 279/688
# Upserted batch 280/688
# Upserted batch 281/688
# Upserted batch 282/688
# Upserted batch 283/688
# Upserted batch 284/688
# Upserted batch 285/688
# Upserted batch 286/688
# Upserted batch 287/688
# Upserted batch 288/688
# Upserted batch 289/688
# Upserted batch 290/688
# Upserted batch 291/688
# Upserted batch 292/688
# Upserted batch 293/688
# Upserted batch 294/688
# Upserted batch 295/688
# Upserted batch 296/688
# Upserted batch 297/688
# Upserted batch 298/688
# Upserted batch 299/688
# Upserted batch 300/688
# Upserted batch 301/688
# Upserted batch 302/688
# Upserted batch 303/688
# Upserted batch 304/688
# Upserted batch 305/688
# Upserted batch 306/688
# Upserted batch 307/688
# Upserted batch 308/688
# Upserted batch 309/688
# Upserted batch 310/688
# Upserted batch 311/688
# Upserted batch 312/688
# Upserted batch 313/688
# Upserted batch 314/688
# Upserted batch 315/688
# Upserted batch 316/688
# Upserted batch 317/688
# Upserted batch 318/688
# Upserted batch 319/688
# Upserted batch 320/688
# Upserted batch 321/688
# Upserted batch 322/688
# Upserted batch 323/688
# Upserted batch 324/688
# Upserted batch 325/688
# Upserted batch 326/688
# Upserted batch 327/688
# Upserted batch 328/688
# Upserted batch 329/688
# Upserted batch 330/688
# Upserted batch 331/688
# Upserted batch 332/688
# Upserted batch 333/688
# Upserted batch 334/688
# Upserted batch 335/688
# Upserted batch 336/688
# Upserted batch 337/688
# Upserted batch 338/688
# Upserted batch 339/688
# Upserted batch 340/688
# Upserted batch 341/688
# Upserted batch 342/688
# Upserted batch 343/688
# Upserted batch 344/688
# Upserted batch 345/688
# Upserted batch 346/688
# Upserted batch 347/688
# Upserted batch 348/688
# Upserted batch 349/688
# Upserted batch 350/688
# Upserted batch 351/688
# Upserted batch 352/688
# Upserted batch 353/688
# Upserted batch 354/688
# Upserted batch 355/688
# Upserted batch 356/688
# Upserted batch 357/688
# Upserted batch 358/688
# Upserted batch 359/688
# Upserted batch 360/688
# Upserted batch 361/688
# Upserted batch 362/688
# Upserted batch 363/688
# Upserted batch 364/688
# Upserted batch 365/688
# Upserted batch 366/688
# Upserted batch 367/688
# Upserted batch 368/688
# Upserted batch 369/688
# Upserted batch 370/688
# Upserted batch 371/688
# Upserted batch 372/688
# Upserted batch 373/688
# Upserted batch 374/688
# Upserted batch 375/688
# Upserted batch 376/688
# Upserted batch 377/688
# Upserted batch 378/688
# Upserted batch 379/688
# Upserted batch 380/688
# Upserted batch 381/688
# Upserted batch 382/688
# Upserted batch 383/688
# Upserted batch 384/688
# Upserted batch 385/688
# Upserted batch 386/688
# Upserted batch 387/688
# Upserted batch 388/688
# Upserted batch 389/688
# Upserted batch 390/688
# Upserted batch 391/688
# Upserted batch 392/688
# Upserted batch 393/688
# Upserted batch 394/688
# Upserted batch 395/688
# Upserted batch 396/688
# Upserted batch 397/688
# Upserted batch 398/688
# Upserted batch 399/688
# Upserted batch 400/688
# Upserted batch 401/688
# Upserted batch 402/688
# Upserted batch 403/688
# Upserted batch 404/688
# Upserted batch 405/688
# Upserted batch 406/688
# Upserted batch 407/688
# Upserted batch 408/688
# Upserted batch 409/688
# Upserted batch 410/688
# Upserted batch 411/688
# Upserted batch 412/688
# Upserted batch 413/688
# Upserted batch 414/688
# Upserted batch 415/688
# Upserted batch 416/688
# Upserted batch 417/688
# Upserted batch 418/688
# Upserted batch 419/688
# Upserted batch 420/688
# Upserted batch 421/688
# Upserted batch 422/688
# Upserted batch 423/688
# Upserted batch 424/688
# Upserted batch 425/688
# Upserted batch 426/688
# Upserted batch 427/688
# Upserted batch 428/688
# Upserted batch 429/688
# Upserted batch 430/688
# Upserted batch 431/688
# Upserted batch 432/688
# Upserted batch 433/688
# Upserted batch 434/688
# Upserted batch 435/688
# Upserted batch 436/688
# Upserted batch 437/688
# Upserted batch 438/688
# Upserted batch 439/688
# Upserted batch 440/688
# Upserted batch 441/688
# Upserted batch 442/688
# Upserted batch 443/688
# Upserted batch 444/688
# Upserted batch 445/688
# Upserted batch 446/688
# Upserted batch 447/688
# Upserted batch 448/688
# Upserted batch 449/688
# Upserted batch 450/688
# Upserted batch 451/688
# Upserted batch 452/688
# Upserted batch 453/688
# Upserted batch 454/688
# Upserted batch 455/688
# Upserted batch 456/688
# Upserted batch 457/688
# Upserted batch 458/688
# Upserted batch 459/688
# Upserted batch 460/688
# Upserted batch 461/688
# Upserted batch 462/688
# Upserted batch 463/688
# Upserted batch 464/688
# Upserted batch 465/688
# Upserted batch 466/688
# Upserted batch 467/688
# Upserted batch 468/688
# Upserted batch 469/688
# Upserted batch 470/688
# Upserted batch 471/688
# Upserted batch 472/688
# Upserted batch 473/688
# Upserted batch 474/688
# Upserted batch 475/688
# Upserted batch 476/688
# Upserted batch 477/688
# Upserted batch 478/688
# Upserted batch 479/688
# Upserted batch 480/688
# Upserted batch 481/688
# Upserted batch 482/688
# Upserted batch 483/688
# Upserted batch 484/688
# Upserted batch 485/688
# Upserted batch 486/688
# Upserted batch 487/688
# Upserted batch 488/688
# Upserted batch 489/688
# Upserted batch 490/688
# Upserted batch 491/688
# Upserted batch 492/688
# Upserted batch 493/688
# Upserted batch 494/688
# Upserted batch 495/688
# Upserted batch 496/688
# Upserted batch 497/688
# Upserted batch 498/688
# Upserted batch 499/688
# Upserted batch 500/688
# Upserted batch 501/688
# Upserted batch 502/688
# Upserted batch 503/688
# Upserted batch 504/688
# Upserted batch 505/688
# Upserted batch 506/688
# Upserted batch 507/688
# Upserted batch 508/688
# Upserted batch 509/688
# Upserted batch 510/688
# Upserted batch 511/688
# Upserted batch 512/688
# Upserted batch 513/688
# Upserted batch 514/688
# Upserted batch 515/688
# Upserted batch 516/688
# Upserted batch 517/688
# Upserted batch 518/688
# Upserted batch 519/688
# Upserted batch 520/688
# Upserted batch 521/688
# Upserted batch 522/688
# Upserted batch 523/688
# Upserted batch 524/688
# Upserted batch 525/688
# Upserted batch 526/688
# Upserted batch 527/688
# Upserted batch 528/688
# Upserted batch 529/688
# Upserted batch 530/688
# Upserted batch 531/688
# Upserted batch 532/688
# Upserted batch 533/688
# Upserted batch 534/688
# Upserted batch 535/688
# Upserted batch 536/688
# Upserted batch 537/688
# Upserted batch 538/688
# Upserted batch 539/688
# Upserted batch 540/688
# Upserted batch 541/688
# Upserted batch 542/688
# Upserted batch 543/688
# Upserted batch 544/688
# Upserted batch 545/688
# Upserted batch 546/688
# Upserted batch 547/688
# Upserted batch 548/688
# Upserted batch 549/688
# Upserted batch 550/688
# Upserted batch 551/688
# Upserted batch 552/688
# Upserted batch 553/688
# Upserted batch 554/688
# Upserted batch 555/688
# Upserted batch 556/688
# Upserted batch 557/688
# Upserted batch 558/688
# Upserted batch 559/688
# Upserted batch 560/688
# Upserted batch 561/688
# Upserted batch 562/688
# Upserted batch 563/688
# Upserted batch 564/688
# Upserted batch 565/688
# Upserted batch 566/688
# Upserted batch 567/688
# Upserted batch 568/688
# Upserted batch 569/688
# Upserted batch 570/688
# Upserted batch 571/688
# Upserted batch 572/688
# Upserted batch 573/688
# Upserted batch 574/688
# Upserted batch 575/688
# Upserted batch 576/688
# Upserted batch 577/688
# Upserted batch 578/688
# Upserted batch 579/688
# Upserted batch 580/688
# Upserted batch 581/688
# Upserted batch 582/688
# Upserted batch 583/688
# Upserted batch 584/688
# Upserted batch 585/688
# Upserted batch 586/688
# Upserted batch 587/688
# Upserted batch 588/688
# Upserted batch 589/688
# Upserted batch 590/688
# Upserted batch 591/688
# Upserted batch 592/688
# Upserted batch 593/688
# Upserted batch 594/688
# Upserted batch 595/688
# Upserted batch 596/688
# Upserted batch 597/688
# Upserted batch 598/688
# Upserted batch 599/688
# Upserted batch 600/688
# Upserted batch 601/688
# Upserted batch 602/688
# Upserted batch 603/688
# Upserted batch 604/688
# Upserted batch 605/688
# Upserted batch 606/688
# Upserted batch 607/688
# Upserted batch 608/688
# Upserted batch 609/688
# Upserted batch 610/688
# Upserted batch 611/688
# Upserted batch 612/688
# Upserted batch 613/688
# Upserted batch 614/688
# Upserted batch 615/688
# Upserted batch 616/688
# Upserted batch 617/688
# Upserted batch 618/688
# Upserted batch 619/688
# Upserted batch 620/688
# Upserted batch 621/688
# Upserted batch 622/688
# Upserted batch 623/688
# Upserted batch 624/688
# Upserted batch 625/688
# Upserted batch 626/688
# Upserted batch 627/688
# Upserted batch 628/688
# Upserted batch 629/688
# Upserted batch 630/688
# Upserted batch 631/688
# Upserted batch 632/688
# Upserted batch 633/688
# Upserted batch 634/688
# Upserted batch 635/688
# Upserted batch 636/688
# Upserted batch 637/688
# Upserted batch 638/688
# Upserted batch 639/688
# Upserted batch 640/688
# Upserted batch 641/688
# Upserted batch 642/688
# Upserted batch 643/688
# Upserted batch 644/688
# Upserted batch 645/688
# Upserted batch 646/688
# Upserted batch 647/688
# Upserted batch 648/688
# Upserted batch 649/688
# Upserted batch 650/688
# Upserted batch 651/688
# Upserted batch 652/688
# Upserted batch 653/688
# Upserted batch 654/688
# Upserted batch 655/688
# Upserted batch 656/688
# Upserted batch 657/688
# Upserted batch 658/688
# Upserted batch 659/688
# Upserted batch 660/688
# Upserted batch 661/688
# Upserted batch 662/688
# Upserted batch 663/688
# Upserted batch 664/688
# Upserted batch 665/688
# Upserted batch 666/688
# Upserted batch 667/688
# Upserted batch 668/688
# Upserted batch 669/688
# Upserted batch 670/688
# Upserted batch 671/688
# Upserted batch 672/688
# Upserted batch 673/688
# Upserted batch 674/688
# Upserted batch 675/688
# Upserted batch 676/688
# Upserted batch 677/688
# Upserted batch 678/688
# Upserted batch 679/688
# Upserted batch 680/688
# Upserted batch 681/688
# Upserted batch 682/688
# Upserted batch 683/688
# Upserted batch 684/688
# Upserted batch 685/688
# Upserted batch 686/688
# Upserted batch 687/688
# Upserted batch 688/688
# Data upserted successfully.

# %%
def runQuery(tokenized_query):
    # Generate query vector
    query_vector = np.zeros(model.vector_size)
    vectorized_query = vectorizer.transform([' '.join(tokenized_query)])
    for word in tokenized_query:
        if word in model.wv and word in vectorizer.vocabulary_:
            tfidf_score = vectorized_query[0, vectorizer.vocabulary_[word]]
            word_vector = model.wv[word]
            query_vector += tfidf_score * word_vector

    # Normalize the query vector
    query_vector = normalize([query_vector])[0]

    # Ensure query vector is in list format and values are floats
    query_vector = [float(x) for x in query_vector]

    # Query Pinecone index
    results = index.query(vector=query_vector, top_k=10, include_values=True)
    # print(results)
    # Retrieve top-k results
    top_k_results = [int(doc['id']) for doc in results['matches']]
    return top_k_results

# %%
# Example usage
tokenized_query = ["example", "query", "terms"]
retrieved_docs = runQuery(tokenized_query)
print("Retrieved documents:", retrieved_docs)
# Out:
# Retrieved documents: [293690, 293746, 294658, 302710, 294659, 144689, 194411, 318946, 170174, 306245]

# %%
def get_relevant_docs_from_qrels(query_id):
    key_str = str(query_id)
    value = links[key_str]
    return value

# %%
def calculate_mrr(relevant_docs, retrieved_docs):
    """
    Calculate the reciprocal rank for a single query.
    
    :param relevant_docs: A set of relevant document IDs.
    :param retrieved_docs: A list of retrieved document IDs.
    :return: The reciprocal rank for the query.
    """
    for rank, doc_id in enumerate(retrieved_docs, start=1):
        if doc_id in relevant_docs:
            return 1 / rank
    return 0

# %%
def calculate_map(relevant_documents_id, retrieved_documents_id, k):
    precision_sum = 0.0
    relevant_count = 0

    if len(relevant_documents_id) == 0 or len(retrieved_documents_id) == 0:
        return 0.0

    retrieved_documents_id = retrieved_documents_id[:k]

    for i, doc_id in enumerate(retrieved_documents_id, 1):
        if doc_id in relevant_documents_id:
            relevant_count += 1
            precision_sum += relevant_count / i

    avg_precision = precision_sum / min(len(relevant_documents_id), k)
    return avg_precision

# %%
def myRunQueries(tokenized_queries):
    ap_at_ak = 0
    total_reciprocal_rank = 0
    
    for query in tokenized_queries:
        print("Query ID:", query['query_id'])
        
        relevant = get_relevant_docs_from_qrels(query['query_id'])
        retrieved = runQuery(query['query_content'])
        retrieved_ids = []
        for doc in retrieved:
            retrieved_ids.append(doc)
            
        print("relevant: ", relevant)
        print("retrieved: ", retrieved_ids)
        
        map_score = calculate_map(relevant, retrieved_ids, 10)
        print("MAP:", map_score)
        print('-------------------------------------------------------------------------')

        ap_at_ak += map_score
        
        reciprocal_rank = calculate_mrr(relevant, retrieved_ids)
        total_reciprocal_rank += reciprocal_rank
    
    map_result = ap_at_ak / len(tokenized_queries)
    mrr = total_reciprocal_rank / len(tokenized_queries)
    
    print("Mean Average Precision (MAP):", map_result)
    print("Mean Reciprocal Rank (MRR):", mrr)
    
    return map_result

# %%
myRunQueries(tokenized_queries)
# Out:
# Query ID: 0
# relevant:  [17292]
# retrieved:  [15653, 6843, 17870, 2983, 37371, 28092, 21039, 17292, 14676, 30165]
# MAP: 0.125
# -------------------------------------------------------------------------
# Query ID: 1
# relevant:  [8854]
# retrieved:  [13014, 11806, 25577, 14019, 29698, 38384, 27446, 31081, 7094, 28412]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 2
# relevant:  [15041]
# retrieved:  [5586, 12332, 12955, 18246, 980, 26487, 195, 1425, 26844, 3444]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 3
# relevant:  [24955]
# retrieved:  [24955, 27103, 21074, 17775, 23076, 18785, 21138, 22266, 18203, 27687]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 4
# relevant:  [2239]
# retrieved:  [21680, 21681, 2239, 16228, 3144, 21682, 5974, 29407, 28967, 10349]
# MAP: 0.3333333333333333
# -------------------------------------------------------------------------
# Query ID: 5
# relevant:  [5559, 5560, 5561, 7647, 28427, 32082, 35255]
# retrieved:  [13741, 30990, 32072, 37118, 17075, 2057, 5559, 22410, 12367, 22412]
# MAP: 0.02040816326530612
# -------------------------------------------------------------------------
# Query ID: 6
# relevant:  [1555, 8371]
# retrieved:  [8395, 15994, 28636, 11393, 23229, 14184, 30008, 14019, 33424, 1594]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 7
# relevant:  [14681, 14694]
# retrieved:  [14763, 14700, 10951, 16456, 22949, 10511, 27252, 32460, 32877, 8595]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 8
# relevant:  [6063]
# retrieved:  [13101, 18130, 276482, 1336, 22923, 37557, 18494, 18407, 37627, 16104]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 9
# relevant:  [16749, 16771, 37703]
# retrieved:  [16749, 24288, 17588, 35802, 23382, 5322, 27972, 28714, 6345, 25769]
# MAP: 0.3333333333333333
# -------------------------------------------------------------------------
# Query ID: 10
# relevant:  [24207]
# retrieved:  [112166, 119667, 171967, 110595, 126982, 130656, 82789, 172919, 124324, 70451]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 11
# relevant:  [4851]
# retrieved:  [10099, 38030, 6497, 38351, 4928, 26152, 34188, 18405, 25849, 21693]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 12
# relevant:  [26492, 26496]
# retrieved:  [15401, 26496, 26492, 14493, 25440, 5565, 11148, 20801, 33058, 28787]
# MAP: 0.5833333333333333
# -------------------------------------------------------------------------
# Query ID: 13
# relevant:  [26492, 26496]
# retrieved:  [26496, 26492, 15401, 25440, 14493, 5565, 11148, 33058, 21531, 28787]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 14
# relevant:  [12987, 12988]
# retrieved:  [21761, 21431, 35492, 20775, 35954, 34153, 19729, 20024, 6538, 30909]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 15
# relevant:  [723, 15764]
# retrieved:  [3518, 7317, 31223, 18165, 27401, 289304, 17326, 3104, 33457, 33395]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 16
# relevant:  [15026, 15029]
# retrieved:  [1976, 24870, 14752, 19402, 18019, 470, 5353, 1820, 19363, 16476]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 17
# relevant:  [830, 1822]
# retrieved:  [1822, 31569, 12311, 38560, 39371, 16454, 28960, 8642, 15019, 38569]
# MAP: 0.5
# -------------------------------------------------------------------------
# Query ID: 18
# relevant:  [5629, 5630, 5631, 5633, 24144]
# retrieved:  [340076, 323451, 37518, 28965, 22472, 483, 26021, 30855, 327719, 24071]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 19
# relevant:  [6858, 6866]
# retrieved:  [6858, 8524, 38530, 28350, 3668, 18423, 22974, 4139, 38586, 25827]
# MAP: 0.5
# -------------------------------------------------------------------------
# Query ID: 20
# relevant:  [723, 15764]
# retrieved:  [723, 25281, 4660, 35749, 22195, 24210, 7317, 17326, 26779, 1894]
# MAP: 0.5
# -------------------------------------------------------------------------
# Query ID: 21
# relevant:  [15151, 15153, 19281]
# retrieved:  [31825, 28706, 10348, 9117, 37678, 28493, 32776, 13913, 6083, 12836]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 22
# relevant:  [16287]
# retrieved:  [17525, 32926, 25948, 14330, 16287, 19316, 39030, 22842, 20303, 29147]
# MAP: 0.2
# -------------------------------------------------------------------------
# Query ID: 23
# relevant:  [2389]
# retrieved:  [12332, 5586, 12955, 980, 4953, 18246, 7798, 26487, 20770, 195]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 24
# relevant:  [11318]
# retrieved:  [33027, 15427, 10567, 5458, 78656, 34306, 284607, 25758, 906, 3255]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 25
# relevant:  [10226, 36757, 36759]
# retrieved:  [36759, 31965, 14684, 13265, 21, 32943, 996, 26645, 23919, 23366]
# MAP: 0.3333333333333333
# -------------------------------------------------------------------------
# Query ID: 26
# relevant:  [2389]
# retrieved:  [12332, 5586, 12955, 980, 18246, 26487, 1708, 4953, 192, 195]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 27
# relevant:  [16627]
# retrieved:  [20770, 5586, 12332, 12955, 26844, 980, 1425, 13830, 6348, 192]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 28
# relevant:  [11563]
# retrieved:  [11563, 33545, 21642, 30792, 29597, 7722, 16419, 29344, 9212, 15957]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 29
# relevant:  [25421]
# retrieved:  [6256, 7607, 27235, 8341, 24773, 28461, 25617, 17901, 12408, 473]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 30
# relevant:  [28552]
# retrieved:  [23829, 154194, 16134, 13412, 43689, 8017, 105719, 91502, 95721, 93851]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 31
# relevant:  [840, 851, 5846]
# retrieved:  [840, 1376, 5846, 31281, 169214, 94473, 18516, 32094, 26674, 26999]
# MAP: 0.5555555555555555
# -------------------------------------------------------------------------
# Query ID: 32
# relevant:  [4420, 18058]
# retrieved:  [23595, 3695, 26535, 7653, 33766, 33038, 33114, 28243, 1702, 226]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 33
# relevant:  [13897, 13898, 13913]
# retrieved:  [32557, 33220, 337102, 7772, 32470, 29601, 9699, 28654, 1174, 30913]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 34
# relevant:  [14835]
# retrieved:  [18535, 5782, 29491, 17305, 31300, 10681, 17304, 11745, 11517, 37904]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 35
# relevant:  [12371, 12374]
# retrieved:  [23666, 16222, 13349, 23939, 27532, 13217, 32370, 28190, 32806, 12356]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 36
# relevant:  [13456]
# retrieved:  [10989, 12709, 12336, 5288, 28674, 16428, 15884, 8199, 12476, 20928]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 37
# relevant:  [24409]
# retrieved:  [35991, 29182, 16676, 24271, 37751, 23395, 10053, 264624, 270342, 24298]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 38
# relevant:  [16090]
# retrieved:  [1823, 2455, 12429, 2959, 15885, 11425, 11839, 8310, 7861, 32092]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 39
# relevant:  [22882]
# retrieved:  [2740, 2625, 26284, 5510, 21999, 8095, 17357, 1071, 15288, 25566]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 40
# relevant:  [11676, 11677]
# retrieved:  [39045, 6712, 4167, 4481, 4851, 20443, 38030, 20804, 29204, 32516]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 41
# relevant:  [5793, 5798, 36986]
# retrieved:  [12837, 16819, 33898, 12277, 2323, 10905, 6575, 13335, 23228, 29612]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 42
# relevant:  [20619]
# retrieved:  [8290, 8672, 7275, 12953, 22029, 14161, 12739, 38970, 7253, 14179]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 43
# relevant:  [11593, 11594, 12053, 19625]
# retrieved:  [92236, 8243, 238927, 3063, 89612, 8211, 201810, 265236, 278922, 30976]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 44
# relevant:  [492, 494]
# retrieved:  [20803, 20217, 5527, 35035, 272500, 494, 34123, 37359, 20624, 10452]
# MAP: 0.08333333333333333
# -------------------------------------------------------------------------
# Query ID: 45
# relevant:  [25376]
# retrieved:  [13237, 9464, 17568, 34874, 25376, 18271, 36958, 4089, 33033, 32256]
# MAP: 0.2
# -------------------------------------------------------------------------
# Query ID: 46
# relevant:  [5170]
# retrieved:  [9959, 12586, 10833, 12766, 37534, 28971, 13817, 7685, 7082, 6075]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 47
# relevant:  [1697]
# retrieved:  [32587, 14237, 16034, 38845, 2589, 13194, 3062, 120910, 15818, 105886]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 48
# relevant:  [2539]
# retrieved:  [23833, 286551, 13159, 288314, 21543, 39032, 11927, 287148, 287241, 23532]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 49
# relevant:  [21497, 21498, 31985]
# retrieved:  [10544, 4957, 12866, 287898, 145591, 116295, 34311, 31180, 275927, 8663]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 50
# relevant:  [13721, 13722]
# retrieved:  [13722, 25201, 32042, 38565, 34388, 4225, 10630, 16224, 12720, 24574]
# MAP: 0.5
# -------------------------------------------------------------------------
# Query ID: 51
# relevant:  [19140]
# retrieved:  [19140, 28701, 13514, 19035, 28190, 32806, 30222, 217, 18640, 34642]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 52
# relevant:  [21276]
# retrieved:  [11578, 35855, 12796, 26449, 150575, 28005, 21276, 30598, 177209, 69109]
# MAP: 0.14285714285714285
# -------------------------------------------------------------------------
# Query ID: 53
# relevant:  [27429, 27430]
# retrieved:  [20803, 20217, 5527, 4003, 35035, 18133, 37359, 10452, 33344, 19692]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 54
# relevant:  [6340, 6341, 10814]
# retrieved:  [18573, 835, 38158, 838, 32585, 343036, 25973, 18770, 21577, 19485]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 55
# relevant:  [2389]
# retrieved:  [2389, 12332, 5586, 980, 26487, 12955, 192, 18246, 1708, 4918]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 56
# relevant:  [1555, 8371]
# retrieved:  [28636, 8395, 11393, 30008, 14019, 15994, 14184, 23229, 18823, 1594]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 57
# relevant:  [16849, 16852, 29981]
# retrieved:  [29981, 32411, 18868, 26222, 34556, 16849, 34644, 2637, 35686, 18623]
# MAP: 0.4444444444444444
# -------------------------------------------------------------------------
# Query ID: 58
# relevant:  [841, 843, 1709, 4119, 4149]
# retrieved:  [3884, 1329, 30180, 269418, 6452, 25184, 24846, 5618, 25194, 264174]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 59
# relevant:  [16749, 16771, 37703]
# retrieved:  [16749, 32870, 22592, 16639, 15180, 7572, 35375, 21668, 24288, 5258]
# MAP: 0.3333333333333333
# -------------------------------------------------------------------------
# Query ID: 60
# relevant:  [20619]
# retrieved:  [20619, 10312, 26333, 1267, 21006, 39263, 30539, 27139, 36292, 28410]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 61
# relevant:  [336, 337, 7445, 13525, 15241]
# retrieved:  [31736, 4219, 31696, 24043, 7000, 15068, 5164, 26659, 26317, 26929]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 62
# relevant:  [9805]
# retrieved:  [4953, 7798, 12332, 35176, 10835, 15837, 6331, 35874, 4471, 19837]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 63
# relevant:  [22504, 24124]
# retrieved:  [11245, 11241, 141, 10161, 11753, 34142, 24124, 287978, 30914, 288517]
# MAP: 0.07142857142857142
# -------------------------------------------------------------------------
# Query ID: 64
# relevant:  [6375, 19420]
# retrieved:  [19502, 6375, 24875, 20315, 26136, 34629, 9808, 19504, 11490, 7968]
# MAP: 0.25
# -------------------------------------------------------------------------
# Query ID: 65
# relevant:  [7662]
# retrieved:  [9800, 19358, 2844, 26937, 14346, 25186, 1241, 23047, 26906, 14866]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 66
# relevant:  [17117, 17125]
# retrieved:  [269277, 31572, 263629, 28867, 29361, 292804, 22902, 267384, 264574, 262082]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 67
# relevant:  [18939, 21762, 21953, 21961]
# retrieved:  [21953, 31364, 3713, 39129, 29043, 38879, 35319, 263294, 3714, 12469]
# MAP: 0.25
# -------------------------------------------------------------------------
# Query ID: 68
# relevant:  [19208, 19213, 19219]
# retrieved:  [28031, 32212, 25419, 277700, 154147, 18840, 19219, 131161, 19208, 16161]
# MAP: 0.12169312169312169
# -------------------------------------------------------------------------
# Query ID: 69
# relevant:  [11096, 16880]
# retrieved:  [19903, 37243, 8567, 26275, 22987, 37658, 8380, 19703, 12421, 21722]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 70
# relevant:  [5559, 5560, 5561, 7647, 28427, 32082, 35255]
# retrieved:  [30990, 5559, 32072, 37118, 17075, 2057, 22410, 26267, 13741, 36204]
# MAP: 0.07142857142857142
# -------------------------------------------------------------------------
# Query ID: 71
# relevant:  [11488]
# retrieved:  [12263, 5316, 12264, 35895, 13841, 2136, 19205, 6062, 29771, 15305]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 72
# relevant:  [303, 304]
# retrieved:  [150238, 83296, 14142, 303, 2060, 28139, 8552, 3679, 6386, 6961]
# MAP: 0.125
# -------------------------------------------------------------------------
# Query ID: 73
# relevant:  [17694, 18771, 19409]
# retrieved:  [38345, 6, 7832, 28682, 12437, 9977, 37448, 32811, 17450, 2932]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 74
# relevant:  [23431, 23432]
# retrieved:  [38159, 22795, 32758, 21127, 36600, 39041, 19446, 38160, 31886, 38182]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 75
# relevant:  [26709, 27999]
# retrieved:  [5732, 20874, 32991, 34227, 30161, 24834, 3732, 10046, 36335, 8570]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 76
# relevant:  [10551]
# retrieved:  [6544, 4533, 3694, 30125, 27713, 7420, 33339, 13243, 23656, 33587]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 77
# relevant:  [14458]
# retrieved:  [23277, 31130, 37757, 20459, 16386, 20430, 38148, 34658, 13714, 8813]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 78
# relevant:  [4685]
# retrieved:  [18590, 3980, 24904, 27725, 2981, 4500, 2943, 281016, 22468, 277704]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 79
# relevant:  [14932, 29682]
# retrieved:  [2261, 265177, 36969, 7466, 26474, 16864, 17273, 18627, 37003, 274475]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 80
# relevant:  [15026, 15029]
# retrieved:  [24870, 34274, 14052, 20127, 470, 25379, 19372, 3625, 26930, 21898]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 81
# relevant:  [24477]
# retrieved:  [38642, 20904, 3343, 33611, 21409, 8516, 9792, 17357, 6261, 35386]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 82
# relevant:  [1823, 3890]
# retrieved:  [3890, 833, 25450, 523, 19105, 33754, 20542, 3253, 973, 11999]
# MAP: 0.5
# -------------------------------------------------------------------------
# Query ID: 83
# relevant:  [5867, 5882]
# retrieved:  [11681, 6209, 2767, 21177, 10261, 9729, 33491, 37807, 18648, 2768]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 84
# relevant:  [20905]
# retrieved:  [380, 15699, 15403, 35839, 22033, 38085, 11986, 39067, 20163, 35062]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 85
# relevant:  [10685, 10687, 22867]
# retrieved:  [280692, 276783, 5819, 16868, 6404, 5821, 22084, 22645, 277440, 276909]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 86
# relevant:  [11318]
# retrieved:  [25367, 32502, 10944, 18221, 15649, 18127, 37495, 35350, 27835, 5626]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 87
# relevant:  [27044]
# retrieved:  [1178, 30342, 28312, 58093, 22472, 12394, 30351, 8592, 16235, 6290]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 88
# relevant:  [2767, 2768]
# retrieved:  [8653, 1675, 37794, 22631, 11692, 29771, 12211, 7133, 5563, 8374]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 89
# relevant:  [553]
# retrieved:  [69905, 319415, 22434, 324287, 324437, 266318, 321551, 261218, 342376, 161819]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 90
# relevant:  [27811]
# retrieved:  [24954, 30701, 8537, 8843, 21925, 22348, 10702, 25066, 14542, 24755]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 91
# relevant:  [31462]
# retrieved:  [26430, 19294, 21999, 25337, 18133, 16697, 38564, 39030, 15326, 8810]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 92
# relevant:  [18208]
# retrieved:  [18702, 85088, 8577, 31462, 36764, 166694, 8492, 28078, 475, 18208]
# MAP: 0.1
# -------------------------------------------------------------------------
# Query ID: 93
# relevant:  [26492, 26496]
# retrieved:  [15401, 26496, 26492, 14493, 5565, 25440, 20801, 11148, 33058, 28787]
# MAP: 0.5833333333333333
# -------------------------------------------------------------------------
# Query ID: 94
# relevant:  [10030, 22494, 33696]
# retrieved:  [10030, 33696, 39272, 24192, 291182, 17694, 6056, 33731, 14678, 26119]
# MAP: 0.6666666666666666
# -------------------------------------------------------------------------
# Query ID: 95
# relevant:  [6073]
# retrieved:  [22691, 16131, 3776, 34468, 10046, 17357, 15327, 9613, 30860, 4656]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 96
# relevant:  [18939, 21762, 21953, 21961]
# retrieved:  [22052, 2270, 18610, 18414, 16409, 38379, 7740, 2943, 26133, 34442]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 97
# relevant:  [15041]
# retrieved:  [5586, 12332, 12955, 18246, 980, 26487, 195, 1425, 26844, 3444]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 98
# relevant:  [23871, 23876]
# retrieved:  [35918, 37378, 7436, 39229, 21383, 26410, 34379, 10719, 13000, 14762]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 99
# relevant:  [2767, 2768]
# retrieved:  [3444, 18246, 21641, 28250, 192, 21177, 10261, 18648, 9729, 6399]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 100
# relevant:  [14072, 14079]
# retrieved:  [338420, 341821, 334721, 321525, 332218, 337930, 328775, 341374, 340881, 325428]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 101
# relevant:  [27429, 27430]
# retrieved:  [20217, 20803, 35035, 18133, 37359, 5527, 2082, 3874, 24799, 34123]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 102
# relevant:  [5873, 5874, 5878]
# retrieved:  [10007, 32728, 30056, 23561, 3989, 681, 25479, 23982, 14007, 3897]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 103
# relevant:  [6533]
# retrieved:  [271910, 265198, 264612, 264998, 290293, 273729, 271379, 268544, 13230, 273641]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 104
# relevant:  [18379]
# retrieved:  [28636, 8395, 30522, 21027, 15994, 23229, 27795, 27644, 29184, 11401]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 105
# relevant:  [17677]
# retrieved:  [24701, 30944, 8786, 24468, 26527, 5885, 6234, 21213, 34246, 21712]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 106
# relevant:  [26383, 26391]
# retrieved:  [11630, 29709, 8632, 24273, 19241, 20420, 34792, 20394, 17264, 29529]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 107
# relevant:  [6856, 6857]
# retrieved:  [6856, 27123, 14710, 4035, 21942, 2915, 6857, 14510, 12056, 29596]
# MAP: 0.6428571428571428
# -------------------------------------------------------------------------
# Query ID: 108
# relevant:  [18743]
# retrieved:  [6614, 3025, 218, 23507, 18617, 20200, 25506, 26808, 7843, 17556]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 109
# relevant:  [6496, 6497]
# retrieved:  [18903, 4717, 6738, 33849, 10087, 28405, 20861, 30449, 6497, 857]
# MAP: 0.05555555555555555
# -------------------------------------------------------------------------
# Query ID: 110
# relevant:  [14914]
# retrieved:  [3380, 37648, 4193, 79019, 9021, 37815, 10766, 303, 8223, 35469]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 111
# relevant:  [17886]
# retrieved:  [36910, 5157, 5509, 17886, 13840, 3913, 21496, 16483, 2059, 3155]
# MAP: 0.25
# -------------------------------------------------------------------------
# Query ID: 112
# relevant:  [6285]
# retrieved:  [288347, 17579, 15168, 4111, 2508, 7830, 9973, 7802, 34811, 1690]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 113
# relevant:  [13496, 16176]
# retrieved:  [13496, 7299, 33676, 31545, 19764, 4051, 39374, 39376, 282431, 30164]
# MAP: 0.5
# -------------------------------------------------------------------------
# Query ID: 114
# relevant:  [7894, 8413]
# retrieved:  [35255, 15398, 30990, 17075, 30101, 2475, 37118, 29838, 2057, 5150]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 115
# relevant:  [8619, 15032, 24429]
# retrieved:  [9220, 38895, 5566, 134671, 164663, 8619, 129148, 233639, 24930, 47541]
# MAP: 0.05555555555555555
# -------------------------------------------------------------------------
# Query ID: 116
# relevant:  [20028]
# retrieved:  [26601, 27006, 6980, 33222, 3551, 28485, 2192, 791, 27595, 913]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 117
# relevant:  [22504, 24124]
# retrieved:  [11245, 11241, 141, 34142, 24124, 11753, 10161, 30915, 287978, 30914]
# MAP: 0.1
# -------------------------------------------------------------------------
# Query ID: 118
# relevant:  [39073]
# retrieved:  [4263, 10153, 9770, 22078, 23605, 3655, 22192, 7603, 15719, 27439]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 119
# relevant:  [21197, 21198]
# retrieved:  [37368, 9532, 27763, 36586, 16352, 21197, 3282, 10669, 1426, 37369]
# MAP: 0.08333333333333333
# -------------------------------------------------------------------------
# Query ID: 120
# relevant:  [1122]
# retrieved:  [20537, 31442, 30042, 2057, 29967, 8731, 5559, 29932, 35958, 7925]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 121
# relevant:  [8621]
# retrieved:  [25392, 38367, 17415, 27902, 20350, 25837, 25393, 6027, 15411, 33737]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 122
# relevant:  [8809, 18153, 29413]
# retrieved:  [8809, 283644, 18153, 283337, 20691, 290846, 283664, 284131, 283678, 283902]
# MAP: 0.5555555555555555
# -------------------------------------------------------------------------
# Query ID: 123
# relevant:  [1908]
# retrieved:  [12409, 20310, 24967, 6951, 17725, 25890, 21868, 25461, 1908, 20650]
# MAP: 0.1111111111111111
# -------------------------------------------------------------------------
# Query ID: 124
# relevant:  [4172, 4173, 4174, 7491]
# retrieved:  [4173, 4174, 28353, 26574, 4172, 23877, 4999, 4835, 25703, 7491]
# MAP: 0.75
# -------------------------------------------------------------------------
# Query ID: 125
# relevant:  [20085]
# retrieved:  [7770, 6179, 5094, 32002, 20866, 28908, 2186, 20085, 16189, 31821]
# MAP: 0.125
# -------------------------------------------------------------------------
# Query ID: 126
# relevant:  [21049, 21055]
# retrieved:  [12792, 18290, 13371, 15188, 25337, 19294, 11513, 385, 17451, 6145]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 127
# relevant:  [8809, 18153, 29413]
# retrieved:  [8809, 18153, 283644, 288082, 284131, 283664, 292179, 12055, 283678, 288872]
# MAP: 0.6666666666666666
# -------------------------------------------------------------------------
# Query ID: 128
# relevant:  [16336]
# retrieved:  [30987, 13040, 32481, 16336, 39275, 20770, 11847, 15041, 38784, 15636]
# MAP: 0.25
# -------------------------------------------------------------------------
# Query ID: 129
# relevant:  [2389]
# retrieved:  [12332, 5586, 12955, 4953, 18246, 20770, 980, 195, 7798, 1425]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 130
# relevant:  [15427]
# retrieved:  [26010, 8768, 27186, 24903, 37703, 20688, 13540, 491, 13237, 4089]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 131
# relevant:  [18592, 25506]
# retrieved:  [3222, 9662, 28569, 281143, 21898, 35226, 11384, 335, 2407, 180]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 132
# relevant:  [10226, 36757, 36759]
# retrieved:  [36759, 31965, 21, 14684, 29093, 26645, 13265, 32943, 23631, 996]
# MAP: 0.3333333333333333
# -------------------------------------------------------------------------
# Query ID: 133
# relevant:  [19958, 19959]
# retrieved:  [4882, 13265, 21034, 19959, 23366, 1414, 15011, 14684, 24019, 25506]
# MAP: 0.125
# -------------------------------------------------------------------------
# Query ID: 134
# relevant:  [12987, 12988]
# retrieved:  [34153, 35492, 21761, 20775, 21431, 35954, 6538, 19729, 30909, 18937]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 135
# relevant:  [16627]
# retrieved:  [20770, 12332, 4547, 32473, 10011, 24628, 32647, 5586, 6348, 27045]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 136
# relevant:  [11676, 11677]
# retrieved:  [4851, 39045, 4167, 4481, 20804, 4296, 38030, 6712, 35173, 18144]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 137
# relevant:  [11577, 11580]
# retrieved:  [13516, 22050, 28498, 8944, 3421, 17357, 38615, 26340, 36693, 20022]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 138
# relevant:  [2539]
# retrieved:  [2539, 18656, 30719, 32166, 31399, 31245, 39032, 39103, 13159, 8359]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 139
# relevant:  [22874, 23166]
# retrieved:  [17410, 9648, 17568, 4882, 13265, 22874, 30532, 1414, 2808, 9809]
# MAP: 0.08333333333333333
# -------------------------------------------------------------------------
# Query ID: 140
# relevant:  [924, 926]
# retrieved:  [7209, 9172, 279301, 26238, 32206, 284083, 27344, 284349, 20285, 16010]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 141
# relevant:  [190, 192, 195, 199, 1282, 1420, 12767]
# retrieved:  [26487, 5586, 12955, 980, 192, 15720, 1708, 4918, 1657, 2389]
# MAP: 0.028571428571428574
# -------------------------------------------------------------------------
# Query ID: 142
# relevant:  [6062]
# retrieved:  [7687, 17288, 37620, 36665, 27371, 15838, 35176, 6331, 26870, 4876]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 143
# relevant:  [6340, 6341, 10814]
# retrieved:  [33592, 36705, 29464, 14097, 12545, 2563, 27284, 36352, 19207, 17385]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 144
# relevant:  [27429, 27430]
# retrieved:  [24799, 3475, 35035, 20217, 11930, 18122, 24080, 272500, 494, 36569]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 145
# relevant:  [9165, 13265]
# retrieved:  [8368, 34233, 6039, 24626, 23115, 31422, 22028, 35759, 37781, 20932]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 146
# relevant:  [12177]
# retrieved:  [9733, 35811, 14848, 15583, 36052, 36133, 15294, 28193, 15194, 129297]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 147
# relevant:  [19889, 19891]
# retrieved:  [36907, 23116, 19891, 34380, 32658, 21510, 23123, 33450, 8789, 35096]
# MAP: 0.16666666666666666
# -------------------------------------------------------------------------
# Query ID: 148
# relevant:  [7413]
# retrieved:  [35162, 21, 19462, 6977, 21034, 33852, 23919, 37859, 37851, 37848]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 149
# relevant:  [11676, 11677]
# retrieved:  [4851, 39045, 4167, 4481, 20804, 4296, 38030, 6712, 35173, 18144]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 150
# relevant:  [26492, 26496]
# retrieved:  [26496, 26492, 15401, 25440, 14493, 5565, 28787, 20801, 38722, 11148]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 151
# relevant:  [52]
# retrieved:  [46951, 112255, 77077, 75445, 78880, 71643, 100739, 44559, 168095, 124350]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 152
# relevant:  [20175, 20188]
# retrieved:  [13795, 26104, 7250, 21757, 12563, 12968, 4091, 24039, 28329, 38728]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 153
# relevant:  [4957]
# retrieved:  [10544, 12866, 4957, 301760, 31180, 83299, 58067, 85236, 55165, 302750]
# MAP: 0.3333333333333333
# -------------------------------------------------------------------------
# Query ID: 154
# relevant:  [26383, 26391]
# retrieved:  [11630, 29709, 8632, 24273, 19241, 20420, 34792, 20394, 17264, 29529]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 155
# relevant:  [8895]
# retrieved:  [3580, 27934, 34752, 4430, 32858, 11787, 4229, 25572, 10197, 12673]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 156
# relevant:  [2767, 2768]
# retrieved:  [5550, 26445, 13657, 1220, 5271, 2768, 10095, 6810, 28197, 35874]
# MAP: 0.08333333333333333
# -------------------------------------------------------------------------
# Query ID: 157
# relevant:  [15896, 15897]
# retrieved:  [4078, 33883, 16688, 2623, 17065, 1839, 4074, 15897, 5535, 8021]
# MAP: 0.0625
# -------------------------------------------------------------------------
# Query ID: 158
# relevant:  [23171, 23172]
# retrieved:  [28037, 20208, 1235, 28808, 2270, 16674, 11627, 14238, 10350, 34442]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 159
# relevant:  [1483, 8543, 12473]
# retrieved:  [14684, 8303, 13265, 6297, 26408, 11718, 2113, 5330, 4882, 996]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 160
# relevant:  [25419]
# retrieved:  [25419, 17231, 277700, 28031, 19219, 28733, 32212, 19208, 15710, 20490]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 161
# relevant:  [924, 926]
# retrieved:  [7209, 9172, 279301, 32491, 27344, 284083, 26238, 23585, 20285, 26364]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 162
# relevant:  [4328]
# retrieved:  [35765, 21153, 283706, 21749, 27754, 273771, 266732, 282408, 34330, 284014]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 163
# relevant:  [25246, 32189, 32194]
# retrieved:  [13000, 35373, 32189, 10445, 23290, 280362, 32194, 341908, 330216, 341864]
# MAP: 0.20634920634920637
# -------------------------------------------------------------------------
# Query ID: 164
# relevant:  [3263, 3264, 3272, 3273]
# retrieved:  [3263, 3272, 34035, 3264, 36126, 13762, 21560, 21758, 8297, 4207]
# MAP: 0.6875
# -------------------------------------------------------------------------
# Query ID: 165
# relevant:  [11963]
# retrieved:  [9050, 2793, 11610, 15892, 20794, 25373, 34440, 22227, 13081, 21670]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 166
# relevant:  [407, 417, 423]
# retrieved:  [417, 28136, 21842, 13069, 38146, 7495, 28129, 35221, 36471, 7442]
# MAP: 0.3333333333333333
# -------------------------------------------------------------------------
# Query ID: 167
# relevant:  [5559, 5560, 5561, 7647, 28427, 32082, 35255]
# retrieved:  [30990, 17075, 32072, 2057, 5559, 22410, 3517, 282789, 5561, 32840]
# MAP: 0.06031746031746032
# -------------------------------------------------------------------------
# Query ID: 168
# relevant:  [30605]
# retrieved:  [127, 38902, 15753, 27449, 9241, 23343, 14073, 25188, 36427, 15666]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 169
# relevant:  [28728]
# retrieved:  [17372, 13811, 33592, 13172, 31806, 17992, 17385, 15170, 26010, 32165]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 170
# relevant:  [1032, 1033, 1043, 1284]
# retrieved:  [37477, 36640, 20209, 262083, 6846, 274750, 7294, 30768, 12426, 23417]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 171
# relevant:  [8515]
# retrieved:  [16873, 12281, 14434, 8515, 2797, 16212, 17796, 22552, 37272, 39236]
# MAP: 0.25
# -------------------------------------------------------------------------
# Query ID: 172
# relevant:  [11700]
# retrieved:  [174196, 181916, 53892, 182341, 167275, 133401, 90813, 134125, 94017, 148805]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 173
# relevant:  [6375, 19420]
# retrieved:  [88099, 317598, 296112, 298198, 250619, 241608, 56793, 18919, 321848, 144034]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 174
# relevant:  [7413]
# retrieved:  [37859, 19462, 35162, 37851, 33852, 21, 37848, 31935, 32452, 23919]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 175
# relevant:  [24301]
# retrieved:  [3406, 27132, 288391, 22296, 38061, 291337, 25998, 33049, 13805, 22586]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 176
# relevant:  [8069]
# retrieved:  [8069, 262178, 290717, 261108, 5283, 276506, 288682, 32216, 282845, 282534]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 177
# relevant:  [1847, 4155]
# retrieved:  [8524, 16267, 19338, 22451, 6912, 38530, 10790, 3668, 9852, 1665]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 178
# relevant:  [27429, 27430]
# retrieved:  [20803, 20217, 4003, 5527, 19692, 35035, 17883, 18133, 1084, 37359]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 179
# relevant:  [16849, 16852, 29981]
# retrieved:  [26222, 16849, 29981, 34644, 29399, 15749, 1867, 18868, 32411, 34556]
# MAP: 0.38888888888888884
# -------------------------------------------------------------------------
# Query ID: 180
# relevant:  [3686, 3701]
# retrieved:  [35989, 8297, 34035, 3272, 3263, 36126, 17267, 23511, 13762, 21758]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 181
# relevant:  [2183]
# retrieved:  [3520, 7400, 17210, 38923, 28032, 16366, 10985, 12082, 164, 165]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 182
# relevant:  [21006]
# retrieved:  [38351, 21693, 10099, 21006, 1832, 20619, 26152, 4928, 6497, 21087]
# MAP: 0.25
# -------------------------------------------------------------------------
# Query ID: 183
# relevant:  [2767, 2768]
# retrieved:  [5271, 26445, 6810, 1220, 37290, 25345, 2768, 3257, 5163, 10982]
# MAP: 0.07142857142857142
# -------------------------------------------------------------------------
# Query ID: 184
# relevant:  [21185]
# retrieved:  [14349, 18649, 5908, 3658, 17153, 19877, 13642, 12408, 31116, 28461]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 185
# relevant:  [81, 83, 1287]
# retrieved:  [4807, 83, 24071, 16447, 81, 9902, 32777, 764, 6486, 30855]
# MAP: 0.3
# -------------------------------------------------------------------------
# Query ID: 186
# relevant:  [3139, 12653]
# retrieved:  [1401, 28201, 10590, 23507, 32865, 2951, 10413, 6614, 4543, 18687]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 187
# relevant:  [1963]
# retrieved:  [35302, 36802, 36684, 25968, 21130, 10486, 16209, 12431, 2345, 39042]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 188
# relevant:  [5586, 5591, 5597]
# retrieved:  [28260, 12955, 980, 6348, 1425, 21212, 5586, 9019, 1708, 20770]
# MAP: 0.047619047619047616
# -------------------------------------------------------------------------
# Query ID: 189
# relevant:  [19208, 19213, 19219]
# retrieved:  [28031, 32212, 25419, 277700, 18840, 19219, 154147, 19208, 131161, 16161]
# MAP: 0.13888888888888887
# -------------------------------------------------------------------------
# Query ID: 190
# relevant:  [29515, 29548]
# retrieved:  [32269, 29768, 32470, 34136, 9238, 32844, 7772, 32263, 5046, 29160]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 191
# relevant:  [21932]
# retrieved:  [20033, 478, 27496, 10592, 1661, 21932, 36342, 36347, 16371, 285676]
# MAP: 0.16666666666666666
# -------------------------------------------------------------------------
# Query ID: 192
# relevant:  [13242, 15375]
# retrieved:  [16866, 33227, 129989, 109257, 77123, 132168, 37749, 2874, 23086, 88865]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 193
# relevant:  [13456]
# retrieved:  [13456, 19487, 25774, 8761, 26030, 33498, 28117, 27282, 12180, 21692]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 194
# relevant:  [18208]
# retrieved:  [18208, 35344, 4412, 36764, 28078, 19968, 10796, 17680, 8087, 18255]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 195
# relevant:  [15166]
# retrieved:  [15166, 16447, 32777, 18012, 6486, 2043, 17070, 23607, 26769, 581]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 196
# relevant:  [15896, 15897]
# retrieved:  [4078, 33883, 16688, 2623, 17065, 1839, 4074, 15897, 5535, 8021]
# MAP: 0.0625
# -------------------------------------------------------------------------
# Query ID: 197
# relevant:  [66]
# retrieved:  [81616, 316179, 315042, 46772, 40415, 53994, 320809, 52275, 86491, 62967]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 198
# relevant:  [9916]
# retrieved:  [7076, 996, 7843, 14684, 32943, 14585, 3853, 14626, 2658, 6784]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 199
# relevant:  [17304, 17305, 17306]
# retrieved:  [23700, 17306, 17305, 4264, 11517, 292, 17971, 35177, 18535, 9316]
# MAP: 0.38888888888888884
# -------------------------------------------------------------------------
# Query ID: 200
# relevant:  [259]
# retrieved:  [237062, 198758, 231247, 251702, 236982, 235766, 259, 213623, 235177, 236138]
# MAP: 0.14285714285714285
# -------------------------------------------------------------------------
# Query ID: 201
# relevant:  [22529, 26443]
# retrieved:  [130079, 132305, 142781, 71432, 90790, 40004, 124595, 157047, 115062, 81241]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 202
# relevant:  [16504, 16505, 33078]
# retrieved:  [16504, 33078, 289686, 293000, 28148, 283640, 29037, 16188, 292898, 283781]
# MAP: 0.6666666666666666
# -------------------------------------------------------------------------
# Query ID: 203
# relevant:  [19711, 19712, 19714]
# retrieved:  [7522, 23335, 1835, 35266, 20515, 14234, 320, 16225, 7158, 15924]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 204
# relevant:  [2389]
# retrieved:  [12332, 5586, 12955, 980, 4953, 18246, 7798, 26487, 20770, 195]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 205
# relevant:  [5006, 5007]
# retrieved:  [5007, 25594, 7948, 12775, 6835, 19032, 29463, 30066, 7908, 26330]
# MAP: 0.5
# -------------------------------------------------------------------------
# Query ID: 206
# relevant:  [2767, 2768]
# retrieved:  [18246, 3444, 21641, 28250, 5586, 12332, 192, 10261, 980, 4953]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 207
# relevant:  [13348]
# retrieved:  [35910, 35940, 35991, 29528, 29538, 29560, 29660, 29808, 35842, 342253]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 208
# relevant:  [362, 383]
# retrieved:  [362, 9199, 33818, 15717, 290034, 30508, 274639, 34424, 275468, 278672]
# MAP: 0.5
# -------------------------------------------------------------------------
# Query ID: 209
# relevant:  [16652]
# retrieved:  [16652, 10862, 35427, 6231, 29631, 12751, 25638, 15119, 25658, 12935]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 210
# relevant:  [12452]
# retrieved:  [14652, 38507, 8242, 35514, 38181, 13512, 3916, 7094, 11486, 21217]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 211
# relevant:  [20833]
# retrieved:  [6983, 6640, 277286, 23438, 280325, 278527, 34794, 276263, 275653, 19384]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 212
# relevant:  [19208, 19213, 19219]
# retrieved:  [28031, 32212, 25419, 277700, 18840, 19219, 154147, 19208, 131161, 20490]
# MAP: 0.13888888888888887
# -------------------------------------------------------------------------
# Query ID: 213
# relevant:  [8160]
# retrieved:  [9039, 26632, 21247, 38155, 28533, 31098, 12154, 28991, 27117, 19106]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 214
# relevant:  [2, 5, 8542, 29910]
# retrieved:  [12393, 38215, 34331, 29032, 2, 2300, 117380, 16583, 90179, 10546]
# MAP: 0.05
# -------------------------------------------------------------------------
# Query ID: 215
# relevant:  [19964, 19966]
# retrieved:  [26430, 16697, 21999, 19294, 25337, 19192, 5012, 39030, 27838, 35048]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 216
# relevant:  [4172, 4173, 4174, 7491]
# retrieved:  [4172, 7491, 12565, 37983, 38613, 28353, 4174, 15283, 10351, 36707]
# MAP: 0.6071428571428571
# -------------------------------------------------------------------------
# Query ID: 217
# relevant:  [2239]
# retrieved:  [14514, 4838, 12305, 2271, 38962, 1191, 16385, 28967, 19152, 20577]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 218
# relevant:  [999, 1253, 1373]
# retrieved:  [36184, 1924, 10841, 14471, 19555, 34820, 19156, 15352, 6749, 10580]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 219
# relevant:  [7385]
# retrieved:  [2145, 19761, 4262, 25427, 19101, 2810, 25893, 32317, 10649, 27639]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 220
# relevant:  [8458, 8489]
# retrieved:  [15076, 13932, 14636, 5077, 17587, 8458, 13647, 34203, 37091, 14643]
# MAP: 0.08333333333333333
# -------------------------------------------------------------------------
# Query ID: 221
# relevant:  [9696, 34630]
# retrieved:  [34630, 20284, 8176, 150, 21599, 8295, 25498, 15511, 36104, 17522]
# MAP: 0.5
# -------------------------------------------------------------------------
# Query ID: 222
# relevant:  [18946]
# retrieved:  [45736, 11195, 120431, 23285, 87650, 127625, 129124, 117908, 168737, 167528]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 223
# relevant:  [3263, 3264, 3272, 3273]
# retrieved:  [3263, 3272, 34035, 3264, 36126, 13762, 21560, 21758, 8297, 4207]
# MAP: 0.6875
# -------------------------------------------------------------------------
# Query ID: 224
# relevant:  [19770]
# retrieved:  [9852, 20464, 31010, 290339, 287399, 1089, 16738, 9179, 10743, 30854]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 225
# relevant:  [6842, 26134]
# retrieved:  [26462, 34818, 28841, 9639, 5738, 29692, 8949, 5755, 34719, 26134]
# MAP: 0.05
# -------------------------------------------------------------------------
# Query ID: 226
# relevant:  [24197]
# retrieved:  [23366, 1414, 4882, 13265, 25626, 14684, 37848, 14486, 34546, 19772]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 227
# relevant:  [4204]
# retrieved:  [4204, 5121, 10833, 18076, 4543, 27088, 23233, 30994, 39388, 28583]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 228
# relevant:  [11534]
# retrieved:  [19728, 20101, 34150, 36349, 36973, 7231, 29865, 10468, 23778, 3997]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 229
# relevant:  [481, 488, 33512, 33543, 35585]
# retrieved:  [6281, 32158, 320, 20402, 6282, 23335, 4419, 12160, 13247, 9521]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 230
# relevant:  [336, 337, 7445, 13525, 15241]
# retrieved:  [31736, 4219, 31696, 24043, 7000, 15068, 5164, 26659, 26317, 26929]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 231
# relevant:  [335]
# retrieved:  [34018, 335, 22260, 6887, 3580, 2938, 25566, 20567, 3025, 33144]
# MAP: 0.5
# -------------------------------------------------------------------------
# Query ID: 232
# relevant:  [335]
# retrieved:  [3580, 34018, 22260, 23527, 20567, 25566, 3025, 8810, 6887, 2938]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 233
# relevant:  [11301, 11305, 19774]
# retrieved:  [343234, 157235, 158225, 54124, 156587, 90728, 269119, 201890, 116515, 138473]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 234
# relevant:  [8768]
# ...
# retrieved:  [280076, 277673, 265424, 277084, 280587, 275486, 277235, 261211, 266380, 275622]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 471
# relevant:  [278590]
# retrieved:  [278590, 277796, 277561, 275004, 277267, 279883, 278991, 279994, 279019, 276154]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 472
# relevant:  [274895]
# retrieved:  [74703, 274895, 280626, 275603, 279273, 277672, 281157, 280860, 281045, 125837]
# MAP: 0.5
# -------------------------------------------------------------------------
# Query ID: 473
# relevant:  [289529, 289531]
# retrieved:  [293049, 293052, 293054, 281776, 289741, 286023, 291128, 290103, 281317, 287927]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 474
# relevant:  [283676, 284106, 285367]
# retrieved:  [284106, 293258, 285367, 278433, 267506, 279816, 277041, 277585, 279111, 275909]
# MAP: 0.5555555555555555
# -------------------------------------------------------------------------
# Query ID: 475
# relevant:  [284374, 289417]
# retrieved:  [293147, 17562, 39040, 35639, 280502, 8397, 3864, 5992, 19267, 284374]
# MAP: 0.05
# -------------------------------------------------------------------------
# Query ID: 476
# relevant:  [284069]
# retrieved:  [292121, 283843, 284069, 284924, 286753, 293034, 289252, 29894, 283468, 285915]
# MAP: 0.3333333333333333
# -------------------------------------------------------------------------
# Query ID: 477
# relevant:  [286428]
# retrieved:  [286428, 292476, 283540, 162989, 287732, 285317, 289837, 279303, 286561, 290668]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 478
# relevant:  [289113, 289115, 290697]
# retrieved:  [283107, 288338, 293116, 284570, 234483, 283419, 284408, 287444, 331865, 287907]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 479
# relevant:  [287183, 288817]
# retrieved:  [287183, 288817, 300303, 77661, 70805, 130887, 147841, 70601, 286565, 32909]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 480
# relevant:  [283833]
# retrieved:  [283833, 149, 283799, 292468, 283800, 293091, 288846, 339844, 285419, 285415]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 481
# relevant:  [288510]
# retrieved:  [288510, 288193, 283703, 293178, 290922, 325888, 288237, 291379, 287310, 288546]
# MAP: 1.0
# -------------------------------------------------------------------------
# Query ID: 482
# relevant:  [284217, 284219]
# retrieved:  [282126, 288415, 292592, 291623, 283262, 289271, 292596, 284469, 291673, 292598]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 483
# relevant:  [289529, 289531]
# retrieved:  [293049, 293054, 281776, 293052, 287927, 286023, 291128, 289741, 281317, 290103]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 484
# relevant:  [284382]
# retrieved:  [290608, 284382, 43442, 124718, 59601, 46571, 288792, 61089, 42846, 40025]
# MAP: 0.5
# -------------------------------------------------------------------------
# Query ID: 485
# relevant:  [284930]
# retrieved:  [245719, 193894, 216111, 216698, 278546, 290328, 189708, 222425, 19743, 277556]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 486
# relevant:  [288545]
# retrieved:  [36739, 38366, 282023, 35149, 282021, 281394, 292779, 9198, 282026, 31658]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 487
# relevant:  [284902, 289657]
# retrieved:  [289657, 283713, 275399, 284902, 284646, 268346, 284680, 17262, 287976, 263964]
# MAP: 0.75
# -------------------------------------------------------------------------
# Query ID: 488
# relevant:  [284217, 284219]
# retrieved:  [288415, 282126, 292592, 291623, 283262, 289271, 292596, 284469, 292598, 283626]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 489
# relevant:  [297779]
# retrieved:  [311141, 307483, 310992, 135175, 308832, 299042, 305076, 315865, 113233, 178546]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 490
# relevant:  [293351, 293479, 293678, 295670, 295698, 296934, 300141, 302213, 303502, 304357, 304995, 309124, 309182]
# retrieved:  [300299, 167428, 298557, 122679, 315660, 152130, 126505, 293351, 305935, 156690]
# MAP: 0.0125
# -------------------------------------------------------------------------
# Query ID: 491
# relevant:  [297410, 297428, 299378, 299861, 302986]
# retrieved:  [302676, 298520, 150314, 164648, 59091, 301634, 104962, 310137, 158502, 309247]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 492
# relevant:  [304095, 304096]
# retrieved:  [302618, 114315, 108373, 132733, 101684, 108839, 47912, 174740, 304764, 48800]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 493
# relevant:  [295111, 295116, 298816]
# retrieved:  [180147, 295116, 151646, 76240, 104442, 172069, 80077, 93960, 97803, 96221]
# MAP: 0.16666666666666666
# -------------------------------------------------------------------------
# Query ID: 494
# relevant:  [309467]
# retrieved:  [310992, 306182, 299042, 178546, 310186, 295113, 122009, 295520, 135175, 310502]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 495
# relevant:  [308204, 308205]
# retrieved:  [101546, 308204, 128197, 101130, 51969, 298159, 92664, 156478, 130733, 52540]
# MAP: 0.25
# -------------------------------------------------------------------------
# Query ID: 496
# relevant:  [299279, 299508, 299762, 309986]
# retrieved:  [108338, 302205, 299954, 313810, 44040, 48992, 121796, 295692, 158898, 39463]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 497
# relevant:  [293616, 293618]
# retrieved:  [79747, 310356, 138530, 170883, 81856, 155241, 301702, 164431, 126245, 126274]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 498
# relevant:  [299279, 299508, 299762, 309986]
# retrieved:  [294738, 177475, 294734, 305335, 141616, 307526, 163511, 306021, 163506, 169894]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 499
# relevant:  [303807, 305738]
# retrieved:  [305738, 61529, 303807, 299722, 157944, 132772, 303966, 117531, 126087, 131032]
# MAP: 0.8333333333333333
# -------------------------------------------------------------------------
# Query ID: 500
# relevant:  [298306, 298307, 298313]
# retrieved:  [136739, 133365, 101078, 90278, 310059, 88924, 63808, 103821, 298307, 126206]
# MAP: 0.037037037037037035
# -------------------------------------------------------------------------
# Query ID: 501
# relevant:  [303827, 303829, 303840, 311133]
# retrieved:  [308095, 176319, 132187, 113038, 308083, 144983, 132188, 176814, 84237, 305950]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 502
# relevant:  [303807, 305738]
# retrieved:  [305738, 61529, 303807, 299722, 157944, 132772, 303966, 117531, 126087, 131032]
# MAP: 0.8333333333333333
# -------------------------------------------------------------------------
# Query ID: 503
# relevant:  [306182]
# retrieved:  [105580, 165348, 126477, 296144, 308832, 135175, 310502, 298307, 98748, 135448]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 504
# relevant:  [317243, 317244, 317249, 317250, 317252, 317253, 318166, 321036, 321040]
# retrieved:  [334818, 324986, 322756, 317018, 317243, 317850, 324371, 318166, 342289, 331808]
# MAP: 0.05
# -------------------------------------------------------------------------
# Query ID: 505
# relevant:  [329254, 329707]
# retrieved:  [320581, 339422, 317009, 318620, 336045, 336202, 332693, 317865, 329504, 336520]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 506
# relevant:  [317405, 317408, 317421, 317428, 318903, 329041, 329625, 329648]
# retrieved:  [317405, 329041, 329625, 340255, 335361, 331793, 329648, 322576, 323892, 319633]
# MAP: 0.4464285714285714
# -------------------------------------------------------------------------
# Query ID: 507
# relevant:  [318614, 318633, 318932, 321456, 321457, 339227]
# retrieved:  [339540, 331437, 339227, 331093, 318932, 324837, 318633, 331869, 334948, 326709]
# MAP: 0.19365079365079366
# -------------------------------------------------------------------------
# Query ID: 508
# relevant:  [317405, 317408, 317421, 317428, 318903, 329041, 329625, 329648]
# retrieved:  [317405, 329041, 329625, 340255, 335361, 331793, 329648, 322576, 323892, 319633]
# MAP: 0.4464285714285714
# -------------------------------------------------------------------------
# Query ID: 509
# relevant:  [320975, 320980, 324058, 326004, 328812]
# retrieved:  [324058, 337192, 336457, 342121, 330757, 330778, 318367, 335521, 332014, 245849]
# MAP: 0.2
# -------------------------------------------------------------------------
# Query ID: 510
# relevant:  [336610, 336612, 336622, 336651, 336652, 336653, 336654]
# retrieved:  [337265, 336610, 336653, 336652, 337325, 327675, 341680, 322128, 334477, 340071]
# MAP: 0.2738095238095238
# -------------------------------------------------------------------------
# Query ID: 511
# relevant:  [319925, 320098, 334977]
# retrieved:  [326696, 330205, 342842, 320898, 326446, 335773, 320993, 334867, 331218, 331882]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 512
# relevant:  [323006, 323017, 326428, 327920, 331688]
# retrieved:  [327920, 325039, 323017, 331705, 338795, 324089, 320625, 186458, 321466, 326710]
# MAP: 0.3333333333333333
# -------------------------------------------------------------------------
# Query ID: 513
# relevant:  [317243, 317244, 317249, 317250, 317252, 317253, 318166, 321036, 321040]
# retrieved:  [334818, 318166, 317849, 317018, 318506, 318266, 322756, 341122, 324986, 327021]
# MAP: 0.05555555555555555
# -------------------------------------------------------------------------
# Query ID: 514
# relevant:  [334073, 340391]
# retrieved:  [334073, 332675, 317939, 318983, 320450, 340786, 328522, 340391, 328568, 338776]
# MAP: 0.625
# -------------------------------------------------------------------------
# Query ID: 515
# relevant:  [320768]
# retrieved:  [326971, 318203, 332843, 226699, 320768, 326277, 330124, 321124, 236301, 325869]
# MAP: 0.2
# -------------------------------------------------------------------------
# Query ID: 516
# relevant:  [317243, 317244, 317249, 317250, 317252, 317253, 318166, 321036, 321040]
# retrieved:  [334818, 318166, 317243, 341122, 317849, 324986, 317018, 327021, 317244, 318506]
# MAP: 0.16666666666666663
# -------------------------------------------------------------------------
# Query ID: 517
# relevant:  [331793, 331800, 331810]
# retrieved:  [317405, 329041, 329625, 340255, 326031, 331810, 326969, 333464, 326790, 323892]
# MAP: 0.05555555555555555
# -------------------------------------------------------------------------
# Query ID: 518
# relevant:  [320052, 320061, 320707, 320708, 329976]
# retrieved:  [318528, 331634, 331631, 325395, 316984, 331245, 79717, 320578, 339479, 338991]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 519
# relevant:  [319925, 320098, 334977]
# retrieved:  [331808, 334052, 339277, 333302, 324989, 319702, 338315, 335895, 331899, 334828]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 520
# relevant:  [319925, 320098, 334977]
# retrieved:  [326446, 320998, 331218, 320252, 326696, 321340, 339246, 335773, 331394, 334867]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 521
# relevant:  [317243, 317244, 317249, 317250, 317252, 317253, 318166, 321036, 321040]
# retrieved:  [334818, 317849, 322772, 338635, 329051, 322756, 317018, 336116, 336471, 317243]
# MAP: 0.011111111111111112
# -------------------------------------------------------------------------
# Query ID: 522
# relevant:  [323753, 340816, 340817, 340821]
# retrieved:  [340816, 333397, 337550, 343238, 318745, 335848, 317999, 325190, 341976, 326202]
# MAP: 0.25
# -------------------------------------------------------------------------
# Query ID: 523
# relevant:  [333130, 333133]
# retrieved:  [326784, 329731, 338635, 321860, 326720, 320775, 321970, 341205, 330677, 319234]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 524
# relevant:  [323006, 323017, 326428, 327920, 331688]
# retrieved:  [327920, 323017, 325039, 331705, 338795, 324089, 320625, 326710, 333364, 318336]
# MAP: 0.4
# -------------------------------------------------------------------------
# Query ID: 525
# relevant:  [325068, 325087, 325442, 329661, 339311]
# retrieved:  [324711, 340198, 325068, 331193, 328490, 329661, 338387, 319692, 319693, 339311]
# MAP: 0.1933333333333333
# -------------------------------------------------------------------------
# Query ID: 526
# relevant:  [320968, 320969, 320971]
# retrieved:  [332302, 320562, 320969, 320968, 319201, 320971, 341207, 338479, 327920, 341211]
# MAP: 0.4444444444444444
# -------------------------------------------------------------------------
# Query ID: 527
# relevant:  [317405, 317408, 317421, 317428, 318903, 329041, 329625, 329648]
# retrieved:  [326346, 326370, 319633, 331793, 335979, 337689, 321972, 323845, 330683, 333841]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 528
# relevant:  [327648, 333545]
# retrieved:  [334833, 150109, 342894, 316789, 337631, 123692, 150096, 333545, 332672, 135437]
# MAP: 0.0625
# -------------------------------------------------------------------------
# Query ID: 529
# relevant:  [322086, 322088, 322089, 322090, 322110, 322165, 337669]
# retrieved:  [255628, 269736, 236270, 239416, 213505, 339494, 255948, 337669, 335501, 213803]
# MAP: 0.017857142857142856
# -------------------------------------------------------------------------
# Query ID: 530
# relevant:  [320496]
# retrieved:  [328236, 168369, 339097, 337666, 330968, 326298, 303666, 178807, 171858, 320061]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 531
# relevant:  [336290, 336291, 336292, 336294]
# retrieved:  [336294, 333578, 339687, 325074, 326775, 334452, 343605, 319830, 328492, 334605]
# MAP: 0.25
# -------------------------------------------------------------------------
# Query ID: 532
# relevant:  [322086, 322088, 322089, 322090, 322110, 322165, 337669]
# retrieved:  [331489, 255944, 218789, 209040, 329960, 324149, 329901, 186969, 338481, 326605]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 533
# relevant:  [327648, 333545]
# retrieved:  [334833, 150109, 342894, 316789, 337631, 123692, 150096, 333545, 332672, 135437]
# MAP: 0.0625
# -------------------------------------------------------------------------
# Query ID: 534
# relevant:  [317513, 317514, 317525, 317549, 319162, 333412, 333413, 333464]
# retrieved:  [319311, 336640, 330857, 329834, 317162, 96275, 339376, 321741, 323700, 222461]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 535
# relevant:  [334073, 340391]
# retrieved:  [334073, 332675, 317939, 318983, 320450, 340786, 328522, 340391, 328568, 338776]
# MAP: 0.625
# -------------------------------------------------------------------------
# Query ID: 536
# relevant:  [323118]
# retrieved:  [336199, 338072, 321041, 336045, 320581, 329504, 325424, 324167, 343062, 343448]
# MAP: 0.0
# -------------------------------------------------------------------------
# Query ID: 537
# relevant:  [331623, 331631, 331634]
# retrieved:  [316984, 318528, 331634, 325395, 339479, 79717, 316983, 342046, 318436, 331245]
# MAP: 0.1111111111111111
# -------------------------------------------------------------------------
# Mean Average Precision (MAP): 0.1500387324487829
# Mean Reciprocal Rank (MRR): 0.23854221986192242
# 0.1500387324487829
